# %% [markdown]
# <a href="https://colab.research.google.com/github/PerfectMach1ne/uni-ai-ml/blob/main/25%2B26%2B27_10_23_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 25.10.23 + nightly 26.10
# ## 🐼🐼🐼🐼🐼🐼🐼🐼

# %%
import pandas as pd

# %% [markdown]
# ### DataFrame

# %%
d = {'imie': ["Anna", "Marcin", "Agnieszka"],
    'nazwisko': ["Kowalska", "Nowak","Malecka"],
    'wiek':[24,21,20],
    'samochod':[False, True,True]}
df = pd.DataFrame(data=d)
df.head()
# Out:
#         imie  nazwisko  wiek  samochod
# 0       Anna  Kowalska    24     False
# 1     Marcin     Nowak    21      True
# 2  Agnieszka   Malecka    20      True

# %% [markdown]
# #### Transpose DF

# %%
df.T
# Out:
#                  0       1          2
# imie          Anna  Marcin  Agnieszka
# nazwisko  Kowalska   Nowak    Malecka
# wiek            24      21         20
# samochod     False    True       True

# %%
columns=list(df.columns)
print("Kolumny: ",columns)
print("Wymiary ramki danych: ",df.shape)
# Out:
# Kolumny:  ['imie', 'nazwisko', 'wiek', 'samochod']
# Wymiary ramki danych:  (3, 4)

# %%
print(df.T.shape)
# Out:
# (4, 3)

# %%
print(df.dtypes) # data types for each column
# Out:
# imie        object
# nazwisko    object
# wiek         int64
# samochod      bool
# dtype: object

# %%
df["imie"]=df["imie"].astype("string")
print(df.dtypes)
# Out:
# imie        string
# nazwisko    object
# wiek         int64
# samochod      bool
# dtype: object

# %% [markdown]
# ### Kolumna istotna - Series!!!!

# %%
print("Kolumna imiona - Series: ")
print(df['imie'])
# Out:
# Kolumna imiona - Series:
# 0         Anna
# 1       Marcin
# 2    Agnieszka
# Name: imie, dtype: string

# %%
print(df.wiek)
print(df['wiek'])
# Out:
# 0    24
# 1    21
# 2    20
# Name: wiek, dtype: int64
# 0    24
# 1    21
# 2    20
# Name: wiek, dtype: int64

# %%
print("Wiersz pod indeksem 2")
print(df.iloc[2])
# Out:
# Wiersz pod indeksem 2
# imie        Agnieszka
# nazwisko      Malecka
# wiek               20
# samochod         True
# Name: 2, dtype: object

# %%
df.iloc[2]
# Out:
# imie        Agnieszka
# nazwisko      Malecka
# wiek               20
# samochod         True
# Name: 2, dtype: object

# %%
df.iloc[2:3]
# Out:
#         imie nazwisko  wiek  samochod
# 2  Agnieszka  Malecka    20      True

# %%
print("Fragment ramki danych - wiersze z indeksami 1 oraz 2")
df.iloc[1:3]
# Out:
# Fragment ramki danych - wiersze z indeksami 1 oraz 2
#         imie nazwisko  wiek  samochod
# 1     Marcin    Nowak    21      True
# 2  Agnieszka  Malecka    20      True

# %%
print("Nazwiska osob spod indeksow 1 oraz 2")
df.iloc[1:3]["nazwisko"]
# Out:
# Nazwiska osob spod indeksow 1 oraz 2
# 1      Nowak
# 2    Malecka
# Name: nazwisko, dtype: object

# %%
df_indexes=df.copy()
print(df_indexes)
df_indexes.index=["s123","s124","s125"]
# Out:
#         imie  nazwisko  wiek  samochod
# 0       Anna  Kowalska    24     False
# 1     Marcin     Nowak    21      True
# 2  Agnieszka   Malecka    20      True

# %%
df_indexes
# Out:
#            imie  nazwisko  wiek  samochod
# s123       Anna  Kowalska    24     False
# s124     Marcin     Nowak    21      True
# s125  Agnieszka   Malecka    20      True

# %%
print("Wiersz pod indeksem s124")
print(df_indexes.loc["s124"])
# Out:
# Wiersz pod indeksem s124
# imie        Marcin
# nazwisko     Nowak
# wiek            21
# samochod      True
# Name: s124, dtype: object

# %% [markdown]
# ### manipulacja kolumnami

# %%
df["srednia_ocen"]=[5.0, 3.5, 4.5]
df.head()
# Out:
#         imie  nazwisko  wiek  samochod  srednia_ocen
# 0       Anna  Kowalska    24     False           5.0
# 1     Marcin     Nowak    21      True           3.5
# 2  Agnieszka   Malecka    20      True           4.5

# %%
emails=["a.kowalska@gmail.com", "m.nowak@gmail.com", "a.malecka@gmail.com"]
df.insert(0, 'email',emails , False) #False oznacza, ze dodawana kolumna nie moze sie duplikowac
df.head()
# Out:
#                   email       imie  nazwisko  wiek  samochod  srednia_ocen
# 0  a.kowalska@gmail.com       Anna  Kowalska    24     False           5.0
# 1     m.nowak@gmail.com     Marcin     Nowak    21      True           3.5
# 2   a.malecka@gmail.com  Agnieszka   Malecka    20      True           4.5

# %%
df.loc[:, ["stypendium"]] = [True, False, True]
# pandas.DataFrame.loc
# Access a group of rows and columns by label(s) or a boolean array.
# Set value for an entire column
# df.loc[:, 'max_speed'] = 30
df.head()
# Out:
#                   email       imie  nazwisko  wiek  samochod  srednia_ocen  \
# 0  a.kowalska@gmail.com       Anna  Kowalska    24     False           5.0
# 1     m.nowak@gmail.com     Marcin     Nowak    21      True           3.5
# 2   a.malecka@gmail.com  Agnieszka   Malecka    20      True           4.5
#
#    stypendium
# 0        True
# 1       False
# 2        True

# %%
df=df.drop("srednia_ocen", axis=1)
df.head()
# Out:
#                   email       imie  nazwisko  wiek  samochod  stypendium
# 0  a.kowalska@gmail.com       Anna  Kowalska    24     False        True
# 1     m.nowak@gmail.com     Marcin     Nowak    21      True       False
# 2   a.malecka@gmail.com  Agnieszka   Malecka    20      True        True

# %%
df_name_surname=df[["imie","nazwisko"]]
df_name_surname.head()
# Out:
#         imie  nazwisko
# 0       Anna  Kowalska
# 1     Marcin     Nowak
# 2  Agnieszka   Malecka

# %%
df_name_surname=df[df.columns[[1,2]]]
df_name_surname.head()
# Out:
#         imie  nazwisko
# 0       Anna  Kowalska
# 1     Marcin     Nowak
# 2  Agnieszka   Malecka

# %%
df.loc[[0, 2], ["imie", "nazwisko"]]
# Out:
#         imie  nazwisko
# 0       Anna  Kowalska
# 2  Agnieszka   Malecka

# %% [markdown]
# #### deprecated warning incoming..

# %%
row={"email":"pwojcik@gmail.com",
     "imie": "Piotr",
     "nazwisko":"Wojcik",
     "wiek":23,
     "samochod":False}
df=df.append(row,ignore_index=True)
df.head()
# Out:
# <ipython-input-31-dc559d4e8fa7>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(row,ignore_index=True)
#                   email       imie  nazwisko  wiek  samochod stypendium
# 0  a.kowalska@gmail.com       Anna  Kowalska    24     False       True
# 1     m.nowak@gmail.com     Marcin     Nowak    21      True      False
# 2   a.malecka@gmail.com  Agnieszka   Malecka    20      True       True
# 3     pwojcik@gmail.com      Piotr    Wojcik    23     False        NaN

# %%
df.loc[4]=row
df.head(10)
# Out:
#                   email       imie  nazwisko  wiek  samochod stypendium
# 0  a.kowalska@gmail.com       Anna  Kowalska    24     False       True
# 1     m.nowak@gmail.com     Marcin     Nowak    21      True      False
# 2   a.malecka@gmail.com  Agnieszka   Malecka    20      True       True
# 3     pwojcik@gmail.com      Piotr    Wojcik    23     False        NaN
# 4     pwojcik@gmail.com      Piotr    Wojcik    23     False        NaN

# %%
df=df.drop(4, axis = 0)
df.head()
# Out:
#                   email       imie  nazwisko  wiek  samochod stypendium
# 0  a.kowalska@gmail.com       Anna  Kowalska    24     False       True
# 1     m.nowak@gmail.com     Marcin     Nowak    21      True      False
# 2   a.malecka@gmail.com  Agnieszka   Malecka    20      True       True
# 3     pwojcik@gmail.com      Piotr    Wojcik    23     False        NaN

# %% [markdown]
# ### Maski! zaawansowane wybierania

# %%
mask=df["wiek"]>22
df_more_22=df[mask]
df_more_22.head()
# Out:
#                   email   imie  nazwisko  wiek  samochod stypendium
# 0  a.kowalska@gmail.com   Anna  Kowalska    24     False       True
# 3     pwojcik@gmail.com  Piotr    Wojcik    23     False        NaN

# %%
mask=df["samochod"]==False
df_without_car=df[mask]
df_without_car.head()
# Out:
#                   email   imie  nazwisko  wiek  samochod stypendium
# 0  a.kowalska@gmail.com   Anna  Kowalska    24     False       True
# 3     pwojcik@gmail.com  Piotr    Wojcik    23     False        NaN

# %%
import numpy as np
df["srednia_ocen"]=[5.0,3.5,4.5,np.nan]
mask=df["srednia_ocen"].isna()
df["srednia_ocen"][mask]=-1 # can be done via iloc
df.head()
# Out:
# <ipython-input-36-96587162a02e>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["srednia_ocen"][mask]=-1 # can be done via iloc
#                   email       imie  nazwisko  wiek  samochod stypendium  \
# 0  a.kowalska@gmail.com       Anna  Kowalska    24     False       True
# 1     m.nowak@gmail.com     Marcin     Nowak    21      True      False
# 2   a.malecka@gmail.com  Agnieszka   Malecka    20      True       True
# 3     pwojcik@gmail.com      Piotr    Wojcik    23     False        NaN
#
#    srednia_ocen
# 0           5.0
# 1           3.5
# 2           4.5
# 3          -1.0

# %%
df["srednia_ocen"]=[5.0,3.5,4.5,np.nan]
df.head()
# Out:
#                   email       imie  nazwisko  wiek  samochod stypendium  \
# 0  a.kowalska@gmail.com       Anna  Kowalska    24     False       True
# 1     m.nowak@gmail.com     Marcin     Nowak    21      True      False
# 2   a.malecka@gmail.com  Agnieszka   Malecka    20      True       True
# 3     pwojcik@gmail.com      Piotr    Wojcik    23     False        NaN
#
#    srednia_ocen
# 0           5.0
# 1           3.5
# 2           4.5
# 3           NaN

# %%
mask=df["srednia_ocen"].isna()
arr = list(mask)
print(arr)
df.iloc[arr]["srednia_ocen"]=-1
# Out:
# [False, False, False, True]
# <ipython-input-55-bebd61dc8c9a>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.iloc[arr]["srednia_ocen"]=-1

# %% [markdown]
# i am onfused and shuttin down, lets do it late r lol

# %%
df = pd.DataFrame(data=d)
df_2=df.copy()
concated_df=pd.concat([df, df_2], ignore_index=True)
concated_df
# Out:
#         imie  nazwisko  wiek  samochod
# 0       Anna  Kowalska    24     False
# 1     Marcin     Nowak    21      True
# 2  Agnieszka   Malecka    20      True
# 3       Anna  Kowalska    24     False
# 4     Marcin     Nowak    21      True
# 5  Agnieszka   Malecka    20      True

# %% [markdown]
# # "26"
# +27.10.23

# %% [markdown]
# ## zabawa w pliki
#
# cont @ "*Zapisywanie ramek danych do pliku.*"

# %%
import os
from pathlib import Path
current_path = Path(os.path.dirname(os.path.abspath("__file__")))
current_path
# Out:
# PosixPath('/content')
